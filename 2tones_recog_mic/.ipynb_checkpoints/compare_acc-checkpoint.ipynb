# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
time_list = ['0.5', '1.0', '5.0', '10.0', '20.0']
ch_num = [19, 9, 5, 3, 1]
model_num = 2
data_num = 4

whole_list = [ ]
for k1 in range(len(ch_num)):
    max_list = [ ]
    for k2 in range(len(time_list)):
        file_name = 'result/model%d/sim_data%d/%dch/%s_acc_te.txt'%(model_num, data_num, \
                                                                    ch_num[k1], time_list[k2])
        te_acc = np.loadtxt(file_name)
        max_list.append(1-np.max(te_acc))
    whole_list.append(max_list)

max_list=[]
for k2 in range(len(time_list)):
    file_name = 'result/model%d/sim_data%d/raw/%s_acc_te.txt'%(model_num, data_num, time_list[k2])
    te_acc = np.loadtxt(file_name)
    max_list.append(1-np.max(te_acc))
whole_list.append(max_list)

####plot
x = np.arange(len(time_list))
width = 0.12

fig, ax = plt.subplots()
rects0 = ax.bar(x - 3*width, whole_list[5], width, label='Raw')
rects1 = ax.bar(x - 2*width, whole_list[4], width, label='1 oscillator')
rects2 = ax.bar(x - width, whole_list[3], width, label='3 oscillator')
rects3 = ax.bar(x, whole_list[2], width, label='5 oscillator')
rects4 = ax.bar(x + width, whole_list[1], width, label='9 oscillator')
rects5 = ax.bar(x + 2*width, whole_list[0], width, label='19 oscillator')

ax.set_ylabel('Error rate', fontsize=14)
ax.set_title('Accuracy comparison', fontsize=15)
ax.set_xticks(x)
ax.set_xticklabels(time_list)
ax.set_xlabel('Time (ms)', fontsize=14)
ax.set_xlim(-1,5)
ax.set_ylim(0,1)
ax.legend()

fig.tight_layout()
plt.savefig('img/model%d_sim%d.png'%(model_num,data_num))
plt.show()
print(np.array(whole_list)[:,0])
# Out:
# [0.52405263 0.642      0.66184211 0.75568421 0.96373684 0.96331579]

# %%
time_list = ['0.5']#, '1.0', '5.0', '10.0', '20.0']
ch_num = [19, 9, 5, 3, 1]
model_num = 2
data_num = 4

whole_list = [ ]
for k1 in range(len(ch_num)):
    max_list = [ ]
    for k2 in range(len(time_list)):
        file_name = 'result/model%d/sim_data%d/%dch_fft/%s_acc_te.txt'%(model_num, data_num, \
                                                                    ch_num[k1], time_list[k2])
        te_acc = np.loadtxt(file_name)
        max_list.append(1-np.max(te_acc))
    whole_list.append(max_list)

max_list=[]
for k2 in range(len(time_list)):
    file_name = 'result/model%d/sim_data%d/raw_fft/%s_acc_te.txt'%(model_num, data_num, time_list[k2])
    te_acc = np.loadtxt(file_name)
    max_list.append(1-np.max(te_acc))
whole_list.append(max_list)

####plot
x = np.arange(len(time_list))
width = 0.12

fig, ax = plt.subplots()
rects0 = ax.bar(x - 3*width, whole_list[5], width, label='raw')
rects1 = ax.bar(x - 2*width, whole_list[4], width, label='1ch')
rects2 = ax.bar(x - width, whole_list[3], width, label='3ch')
rects3 = ax.bar(x, whole_list[2], width, label='5ch')
rects4 = ax.bar(x + width, whole_list[1], width, label='9ch')
rects5 = ax.bar(x + 2*width, whole_list[0], width, label='19ch')

ax.set_ylabel('Error rate')
ax.set_title('Accuracy comparison')
ax.set_xticks(x)
ax.set_xticklabels(time_list)
ax.set_xlabel('time (ms)')
ax.set_xlim(-1,5)
ax.set_ylim(0,1)
ax.legend()

fig.tight_layout()
plt.savefig('img/model%d_sim%d_fft.png'%(model_num,data_num))
plt.show()

# %%
time_list = ['0.5', '1.0', '5.0', '10.0', '20.0']
ch_num = [19, 9, 5, 3, 1]
model_num = 2
data_num = 5

whole_list = [ ]
for k1 in range(len(ch_num)):
    max_list = [ ]
    for k2 in range(len(time_list)):
        file_name = 'result/model%d/sim_data%d/%dch_2/%s_acc_te.txt'%(model_num, data_num, \
                                                                    ch_num[k1], time_list[k2])
        te_acc = np.loadtxt(file_name)
        max_list.append(1-np.max(te_acc))
    whole_list.append(max_list)
    
max_list=[]
for k2 in range(len(time_list)):
    file_name = 'result/model%d/sim_data%d/19ch_1/%s_acc_te.txt'%(model_num, data_num, time_list[k2])
    te_acc = np.loadtxt(file_name)
    max_list.append(1-np.max(te_acc))
whole_list.append(max_list)

max_list=[]
for k2 in range(len(time_list)):
    file_name = 'result/model%d/sim_data%d/raw/%s_acc_te.txt'%(model_num, data_num, time_list[k2])
    te_acc = np.loadtxt(file_name)
    max_list.append(1-np.max(te_acc))
whole_list.append(max_list)

max_list=[]
for k2 in range(len(time_list)):
    file_name = 'result/model%d/sim_data%d/19ch_3/%s_acc_te.txt'%(model_num, data_num, time_list[k2])
    te_acc = np.loadtxt(file_name)
    max_list.append(1-np.max(te_acc))
whole_list.append(max_list)

####plot
x = np.arange(len(time_list))
width = 0.12

fig, ax = plt.subplots()

rects0 = ax.bar(x - 3*width, whole_list[6], width, label='raw')
rects1 = ax.bar(x - 2*width, whole_list[5], width, label='19ch_1')
rects2 = ax.bar(x - width, whole_list[7], width, label='19ch_3')
rects3 = ax.bar(x, whole_list[4], width, label='1ch')
rects4 = ax.bar(x + width, whole_list[3], width, label='3ch')
rects5 = ax.bar(x + 2*width, whole_list[2], width, label='5ch')
rects6 = ax.bar(x + 3*width, whole_list[1], width, label='9ch')
rects7 = ax.bar(x + 4*width, whole_list[0], width, label='19ch')


ax.set_ylabel('Error rate')
ax.set_title('Accuracy comparison')
ax.set_xticks(x)
ax.set_xticklabels(time_list)
ax.set_xlabel('time (ms)')
ax.set_xlim(-1,6)
ax.set_ylim(0,1)
ax.legend()

fig.tight_layout()
plt.savefig('img/model%d_sim%d.png'%(model_num,data_num))
plt.show()
