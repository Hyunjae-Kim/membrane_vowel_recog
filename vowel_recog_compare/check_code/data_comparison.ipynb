# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
time_len = 10
t_div = int(20/time_len)
div_num = 20*t_div
raw_data = np.load('npy_data/raw/raw_%.1fms_testX.npy'%time_len)
fft_data = np.load('npy_data/fft/fft_%.1fms_testX.npy'%time_len)
mfcc_data = np.load('npy_data/mfcc/mfcc_%.1fms_testX.npy'%time_len)
mem_data = np.load('npy_data/mem/mem_%.1fms_testX.npy'%time_len)

label_check = np.load('npy_data/raw/raw_%.1fms_testY.npy'%time_len)
print('raw :', np.shape(raw_data))
print('fft :', np.shape(fft_data))
print('mfcc:', np.shape(mfcc_data))
print('mem :', np.shape(mem_data))
# Out:
# raw : (3000, 450)
# fft : (3000, 226)
# mfcc: (3000, 20)
# mem : (3000, 10, 100)

# %%
fft_data[k*5*20*t_div]

# %%
for v in range(5):
    for k in range(10):
        num_k = k*5*div_num
        dX = fft_data[num_k + v*div_num][:int(len(fft_data[0])/2)]
        dX2 = raw_data[num_k + v*div_num: num_k+(v+1)*div_num].reshape(-1)
        if np.mean(dX)<0.001:
            print(k, v)
            plt.plot(dX, 'r')
#         else:
#             plt.plot(dX)
            plt.show()
            plt.plot(dX2)
            plt.show()
# Out:
# 6 0

# %%
for k in range(10):
    num_k = k*5*div_num
    f = plt.figure(figsize=(20,3))
    for v in range(5):
        dX = fft_data[num_k + v*div_num][:int(len(fft_data[0])/2)]
        plt.subplot('15%s'%(v+1))
        
#         plt.imshow(dX, vmax=0.0005, vmin=-0.0003)
        plt.plot(dX)
#         plt.title(vowel_list[v])
#         plt.xticks([],[])
#         plt.yticks([],[])

# %%
for k in range(10):
    num_k = k*5*div_num
    f = plt.figure(figsize=(20,3))
    for v in range(5):
        dX = mfcc_data[num_k + v*div_num]#[:int(len(fft_data[0])/2)]
        plt.subplot('15%s'%(v+1))
        
#         plt.imshow(dX, vmax=0.0005, vmin=-0.0003)
        plt.plot(dX)

# %%
print('raw data')
plt.plot(raw_data[0])
plt.show()

print('fft data')
for k in range(10):
    plt.plot(fft_data[k*60])
    plt.show()

print('mfcc data')
for k in range(1000):
    plt.plot(mfcc_data[k*2])
plt.show()
# Out:
# raw data
# fft data
# mfcc data
