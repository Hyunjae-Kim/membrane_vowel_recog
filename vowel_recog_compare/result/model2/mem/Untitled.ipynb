# %%
import numpy as np
import matplotlib.pyplot as plt

tr = np.loadtxt('10.0_loss_tr.txt')
te = np.loadtxt('10.0_loss_te.txt')
plt.plot(tr[:50], 'k')
plt.plot(te[:50], 'r')
plt.show()

# %%
tr = np.loadtxt('10.0_loss_tr.txt')
te = np.loadtxt('10.0_loss_te.txt')
plt.plot(tr[:50], 'k')
plt.plot(te[:50], 'r')
plt.show()
