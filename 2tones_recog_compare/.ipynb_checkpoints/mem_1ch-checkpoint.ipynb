# %%
import os
import time
import shutil
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils as utils
import torch.nn.init as init
from torchvision import datasets

# %%
data_type = 'mem'
model_num = 2
ch_pick=2
time_len =  0.5  ## ms

point_len = int(np.ceil(time_len*5))
fc_len = int(point_len/32)+1

# %%
class Model(nn.Module):
    def __init__(self, loss):
        super(Model, self).__init__()
        input_c = 1
        channel = 32
        self.conv1 = nn.Sequential(
            nn.Conv1d(input_c, channel, kernel_size=5, stride=2, padding=2),
            nn.LeakyReLU(negative_slope=0.1),
            nn.BatchNorm1d(channel))
        self.conv2 = nn.Sequential(
            nn.Conv1d(channel, channel*2, kernel_size=5, stride=2, padding=2),
            nn.LeakyReLU(negative_slope=0.1),
            nn.BatchNorm1d(channel*2))
        self.conv3 = nn.Sequential(
            nn.Conv1d(channel*2, channel*2, kernel_size=5, stride=2, padding=2),
            nn.LeakyReLU(negative_slope=0.1),
            nn.BatchNorm1d(channel*2))
        self.conv4 = nn.Sequential(
            nn.Conv1d(channel*2, channel*4, kernel_size=5, stride=2, padding=2),
            nn.LeakyReLU(negative_slope=0.1),
            nn.BatchNorm1d(channel*4))
        self.conv5 = nn.Sequential(
            nn.Conv1d(channel*4, channel*4, kernel_size=5, stride=2, padding=2),
            nn.LeakyReLU(negative_slope=0.1),
            nn.BatchNorm1d(channel*4))
        self.fc1 = nn.Sequential(
            nn.Linear(channel*4*fc_len, 1024),
            nn.LeakyReLU(negative_slope=0.1),
            nn.BatchNorm1d(1024))
        self.fc2 = nn.Sequential(
            nn.Linear(1024, 20),
            nn.Softmax(dim=1))
        self.loss = loss
        
    def forward(self, data, target):
        x = self.conv1(data)
#         print('1',x.size())
        x = self.conv2(x)
#         print('2',x.size())
        x = self.conv3(x)
#         print('3',x.size())
        x = self.conv4(x)
#         print('4',x.size())
        x = self.conv5(x)
#         print('5',x.size())
        x = x.view(x.size()[0],-1)
#         print('fc', x.size())
        x = self.fc1(x)
#         print('8',x.size())
        h = self.fc2(x)
#         print('9',h.size())
        
        l = self.loss(h, target)
        return l, h, target

# %%
def train(model, trainX, trainY, batch, device, optimizer, train_loss, train_acc):
    model.train()
    dloss = 0
    dacc = 0
    
    rand = torch.randperm(trainX.size()[0])
    trainX = trainX[rand]
    trainY = trainY[rand]
    
    for i in range(batch[0]):
        optimizer.zero_grad()
        loss, output, target = model(trainX[i*batch[1]:(i+1)*batch[1]], trainY[i*batch[1]:(i+1)*batch[1]])
        loss = loss.sum()
        loss.backward()
        optimizer.step()
        _, output = torch.topk(output, 2)
        output, _ = output.sort()
        _, target = torch.topk(target, 2)
        target, _ = target.sort()
        
        dloss += loss.cpu().item()
        dacc += torch.sum(torch.sum(output==target, 1)==2).item()
        
    train_loss.append(dloss/batch[0])
    train_acc.append(dacc/(batch[0]*batch[1]))
    return train_loss, train_acc

def test(model, testX, testY, device, test_loss, test_acc):
    model.eval()
    loss, output, target = model(testX, testY)
    loss = loss.sum()
    
    _, output = torch.topk(output, 2)
    output, _ = output.sort()
    _, target = torch.topk(target, 2)
    target, _ = target.sort()
    
    test_loss.append(loss.cpu().item())
    test_acc.append(torch.sum(torch.sum(output==target, 1)==2).item()/len(testX))
    return test_loss, test_acc, output, target

# %%
if __name__=='__main__':
    print('[Training]%s_%.1f_model%d'%(data_type, time_len, model_num))
    torch.manual_seed(37)
    torch.cuda.manual_seed_all(37)
    torch.backends.cudnn.deterministic = True
    
    trainX = np.load('npy_data/%s/%s_%.1fms_trainX.npy'%(data_type, data_type, time_len))
    trainY = np.load('npy_data/%s/%s_%.1fms_trainY.npy'%(data_type, data_type, time_len))
    testX = np.load('npy_data/%s/%s_%.1fms_testX.npy'%(data_type, data_type, time_len))
    testY = np.load('npy_data/%s/%s_%.1fms_testY.npy'%(data_type, data_type, time_len))

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
    batch_num = 1000
    batch = [int(len(trainX)/batch_num), batch_num]
    
    trainX = torch.Tensor(trainX).to(device)[:,ch_pick-1,:].view(-1,1,point_len)
    trainY = torch.Tensor(trainY).to(device)
    testX = torch.Tensor(testX).to(device)[:,ch_pick-1,:].view(-1,1,point_len)
    testY = torch.Tensor(testY).to(device)
    print('mem data shape  -  %.1f ms'%time_len)
    print('train set :', np.shape(trainX) , np.shape(trainY))
    print('test set :', np.shape(testX) ,np.shape(testY))
# Out:
# [Training]mem_0.5_model2
# mem data shape  -  0.5 ms
# train set : torch.Size([760000, 1, 3]) torch.Size([760000, 20])
# test set : torch.Size([76000, 1, 3]) torch.Size([76000, 20])

# %%
    learning_rate = 0.005
    loss_func=nn.BCELoss()
    model = nn.DataParallel(Model(loss_func)).to(device)
#     model = Model(loss_func).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=batch_num, eta_min = 3e-6)

#     model.load_state_dict(torch.load('ckpt/model%d/%s/%.1f_ckpt_1000.pt'%(model_num, data_type, time_len)))
    a = time.time()
    train_loss = []
    train_acc = []
    test_loss = []
    test_acc = []
    for epoch in range(101):
        train_loss, train_acc = train(model, trainX, trainY, batch, device, optimizer, train_loss, train_acc)
        test_loss, test_acc, output, target = test(model, testX, testY, device, test_loss, test_acc)
        scheduler.step()
        
        if epoch%1==0:
            print('epoch %d - train loss : %.7f  /  test loss : %.7f'%(epoch, train_loss[-1], test_loss[-1]))
            print('           train acc : %.7f  /  test acc : %.7f'%(train_acc[-1], test_acc[-1]))
        if epoch%50==0:
            print('@@@@@@@ save model : epoch %d'% epoch)
            torch.save(model.state_dict(),'ckpt/model%d_1ch/%s/2_%.1f_ckpt_%d.pt'%(model_num, data_type, time_len, epoch))
            np.savetxt('result/model%d_1ch/%s/2_%.1f_loss_tr.txt'%(model_num, data_type, time_len), train_loss)
            np.savetxt('result/model%d_1ch/%s/2_%.1f_loss_te.txt'%(model_num, data_type, time_len), test_loss)
            np.savetxt('result/model%d_1ch/%s/2_%.1f_acc_tr.txt'%(model_num, data_type, time_len), train_acc)
            np.savetxt('result/model%d_1ch/%s/2_%.1f_acc_te.txt'%(model_num, data_type, time_len), test_acc)
    print("training complete! - calculation time :", time.time()-a, '  seconds')
# Out:
# /opt/anaconda3/envs/khj/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:61: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# epoch 0 - train loss : 0.6845482  /  test loss : 0.6793464
#            train acc : 0.0109658  /  test acc : 0.0147368
# @@@@@@@ save model : epoch 0
# epoch 1 - train loss : 0.6721172  /  test loss : 0.6774064
#            train acc : 0.0163158  /  test acc : 0.0134079
# epoch 2 - train loss : 0.6708130  /  test loss : 0.6830661
#            train acc : 0.0173474  /  test acc : 0.0125132
# epoch 3 - train loss : 0.6699156  /  test loss : 0.6852585
#            train acc : 0.0181039  /  test acc : 0.0144211
# epoch 4 - train loss : 0.6693994  /  test loss : 0.6869475
#            train acc : 0.0189053  /  test acc : 0.0121184
# epoch 5 - train loss : 0.6690069  /  test loss : 0.6729172
#            train acc : 0.0193987  /  test acc : 0.0195526
# epoch 6 - train loss : 0.6687299  /  test loss : 0.6686631
#            train acc : 0.0194395  /  test acc : 0.0197368
# epoch 7 - train loss : 0.6682876  /  test loss : 0.6679469
#            train acc : 0.0198513  /  test acc : 0.0227763
# epoch 8 - train loss : 0.6680798  /  test loss : 0.6678894
#            train acc : 0.0203961  /  test acc : 0.0194737
# epoch 9 - train loss : 0.6678512  /  test loss : 0.6682569
#            train acc : 0.0205789  /  test acc : 0.0217895
# epoch 10 - train loss : 0.6676243  /  test loss : 0.6682393
#            train acc : 0.0203671  /  test acc : 0.0209342
# epoch 11 - train loss : 0.6675008  /  test loss : 0.6766608
#            train acc : 0.0206013  /  test acc : 0.0153816
# epoch 12 - train loss : 0.6671766  /  test loss : 0.6709080
#            train acc : 0.0208605  /  test acc : 0.0187632
# epoch 13 - train loss : 0.6670955  /  test loss : 0.6778329
#            train acc : 0.0214368  /  test acc : 0.0170000
# epoch 14 - train loss : 0.6668381  /  test loss : 0.6670055
#            train acc : 0.0212566  /  test acc : 0.0225921
# epoch 15 - train loss : 0.6666921  /  test loss : 0.6740489
#            train acc : 0.0215118  /  test acc : 0.0184079
# epoch 16 - train loss : 0.6665695  /  test loss : 0.6680067
#            train acc : 0.0217566  /  test acc : 0.0226579
# epoch 17 - train loss : 0.6663418  /  test loss : 0.7108819
#            train acc : 0.0219237  /  test acc : 0.0117368
# epoch 18 - train loss : 0.6662053  /  test loss : 0.7498002
#            train acc : 0.0220289  /  test acc : 0.0083026
# epoch 19 - train loss : 0.6661587  /  test loss : 0.7636114
#            train acc : 0.0222553  /  test acc : 0.0067368
# epoch 20 - train loss : 0.6660237  /  test loss : 0.6995033
#            train acc : 0.0223224  /  test acc : 0.0120000
# epoch 21 - train loss : 0.6659875  /  test loss : 0.9216142
#            train acc : 0.0222697  /  test acc : 0.0055526
# epoch 22 - train loss : 0.6658490  /  test loss : 1.0490320
#            train acc : 0.0226053  /  test acc : 0.0051316
# epoch 23 - train loss : 0.6657621  /  test loss : 0.6931179
#            train acc : 0.0225605  /  test acc : 0.0146053
# epoch 24 - train loss : 0.6656605  /  test loss : 0.7058514
#            train acc : 0.0227895  /  test acc : 0.0116579
# epoch 25 - train loss : 0.6655505  /  test loss : 0.6857536
#            train acc : 0.0230526  /  test acc : 0.0155658
# epoch 26 - train loss : 0.6655159  /  test loss : 0.6725721
#            train acc : 0.0229145  /  test acc : 0.0205658
# epoch 27 - train loss : 0.6654135  /  test loss : 0.6670609
#            train acc : 0.0229618  /  test acc : 0.0233684
# epoch 28 - train loss : 0.6653526  /  test loss : 0.7232341
#            train acc : 0.0234737  /  test acc : 0.0111842
# epoch 29 - train loss : 0.6653012  /  test loss : 0.6778923
#            train acc : 0.0231579  /  test acc : 0.0171447
# epoch 30 - train loss : 0.6652382  /  test loss : 0.7262027
#            train acc : 0.0232316  /  test acc : 0.0097632
# epoch 31 - train loss : 0.6651510  /  test loss : 0.7210177
#            train acc : 0.0234092  /  test acc : 0.0093158
# epoch 32 - train loss : 0.6651638  /  test loss : 0.7521186
#            train acc : 0.0235316  /  test acc : 0.0064868
# epoch 33 - train loss : 0.6650540  /  test loss : 0.6834534
#            train acc : 0.0236592  /  test acc : 0.0140526
# epoch 34 - train loss : 0.6649279  /  test loss : 0.6804714
#            train acc : 0.0236816  /  test acc : 0.0148816
# epoch 35 - train loss : 0.6648786  /  test loss : 0.6918411
#            train acc : 0.0237250  /  test acc : 0.0157237
# epoch 36 - train loss : 0.6647951  /  test loss : 0.7097050
#            train acc : 0.0240316  /  test acc : 0.0117895
# epoch 37 - train loss : 0.6648210  /  test loss : 0.6691766
#            train acc : 0.0237092  /  test acc : 0.0223026
# epoch 38 - train loss : 0.6647581  /  test loss : 0.6676686
#            train acc : 0.0241303  /  test acc : 0.0230526
# epoch 39 - train loss : 0.6646628  /  test loss : 0.7325161
#            train acc : 0.0238776  /  test acc : 0.0101579
# epoch 40 - train loss : 0.6646427  /  test loss : 0.7761018
#            train acc : 0.0243592  /  test acc : 0.0069211
# epoch 41 - train loss : 0.6646432  /  test loss : 0.6900526
#            train acc : 0.0238789  /  test acc : 0.0168553
# epoch 42 - train loss : 0.6645686  /  test loss : 0.6662390
#            train acc : 0.0242987  /  test acc : 0.0228289
# epoch 43 - train loss : 0.6644965  /  test loss : 0.6746361
#            train acc : 0.0243092  /  test acc : 0.0194342
# epoch 44 - train loss : 0.6644601  /  test loss : 0.6692917
#            train acc : 0.0243329  /  test acc : 0.0221842
# epoch 45 - train loss : 0.6643914  /  test loss : 0.6637272
#            train acc : 0.0246105  /  test acc : 0.0242237
# epoch 46 - train loss : 0.6643597  /  test loss : 0.6994551
#            train acc : 0.0245461  /  test acc : 0.0136579
# epoch 47 - train loss : 0.6642466  /  test loss : 0.6724565
#            train acc : 0.0248658  /  test acc : 0.0188421
# epoch 48 - train loss : 0.6642584  /  test loss : 0.6675284
#            train acc : 0.0246289  /  test acc : 0.0230263
# epoch 49 - train loss : 0.6642219  /  test loss : 0.8068447
#            train acc : 0.0243184  /  test acc : 0.0086053
# epoch 50 - train loss : 0.6641496  /  test loss : 0.6905252
#            train acc : 0.0248434  /  test acc : 0.0140921
# @@@@@@@ save model : epoch 50
# epoch 51 - train loss : 0.6641590  /  test loss : 0.6844712
#            train acc : 0.0245882  /  test acc : 0.0181711
# epoch 52 - train loss : 0.6640592  /  test loss : 0.7019567
#            train acc : 0.0247053  /  test acc : 0.0117237
# epoch 53 - train loss : 0.6640211  /  test loss : 0.7575629
#            train acc : 0.0247474  /  test acc : 0.0091316
# epoch 54 - train loss : 0.6640465  /  test loss : 0.6636959
#            train acc : 0.0245697  /  test acc : 0.0259868
# epoch 55 - train loss : 0.6639256  /  test loss : 0.6705312
#            train acc : 0.0250711  /  test acc : 0.0214474
# epoch 56 - train loss : 0.6638213  /  test loss : 0.6691991
#            train acc : 0.0255408  /  test acc : 0.0232500
# epoch 57 - train loss : 0.6638653  /  test loss : 0.6674281
#            train acc : 0.0252355  /  test acc : 0.0242763
# epoch 58 - train loss : 0.6637971  /  test loss : 0.6702325
#            train acc : 0.0250013  /  test acc : 0.0237105
# epoch 59 - train loss : 0.6638425  /  test loss : 0.6975706
#            train acc : 0.0255368  /  test acc : 0.0127237
# epoch 60 - train loss : 0.6637153  /  test loss : 0.6647743
#            train acc : 0.0252250  /  test acc : 0.0250000
# epoch 61 - train loss : 0.6637761  /  test loss : 0.6659625
#            train acc : 0.0253605  /  test acc : 0.0253816
# epoch 62 - train loss : 0.6637543  /  test loss : 0.7081904
#            train acc : 0.0253737  /  test acc : 0.0122763
# epoch 63 - train loss : 0.6637165  /  test loss : 0.6810297
#            train acc : 0.0254697  /  test acc : 0.0182237
# epoch 64 - train loss : 0.6635669  /  test loss : 0.6866579
#            train acc : 0.0252434  /  test acc : 0.0138684
# epoch 65 - train loss : 0.6635745  /  test loss : 0.6682661
#            train acc : 0.0257421  /  test acc : 0.0232368
# epoch 66 - train loss : 0.6635478  /  test loss : 0.6711866
#            train acc : 0.0253408  /  test acc : 0.0212500
# epoch 67 - train loss : 0.6635321  /  test loss : 0.6637948
#            train acc : 0.0259066  /  test acc : 0.0258158
# epoch 68 - train loss : 0.6635383  /  test loss : 0.6670789
#            train acc : 0.0255118  /  test acc : 0.0235921
# epoch 69 - train loss : 0.6634293  /  test loss : 0.6677747
#            train acc : 0.0256303  /  test acc : 0.0215526
# epoch 70 - train loss : 0.6633804  /  test loss : 0.7847354
#            train acc : 0.0256618  /  test acc : 0.0072500
# epoch 71 - train loss : 0.6634911  /  test loss : 0.6798854
#            train acc : 0.0258868  /  test acc : 0.0184605
# epoch 72 - train loss : 0.6633113  /  test loss : 0.6801384
#            train acc : 0.0259145  /  test acc : 0.0180263
# epoch 73 - train loss : 0.6633495  /  test loss : 0.6867632
#            train acc : 0.0259566  /  test acc : 0.0176447
# epoch 74 - train loss : 0.6632757  /  test loss : 0.6726947
#            train acc : 0.0255263  /  test acc : 0.0217500
# epoch 75 - train loss : 0.6633513  /  test loss : 0.6797903
#            train acc : 0.0256053  /  test acc : 0.0191316
# epoch 76 - train loss : 0.6633002  /  test loss : 0.6709753
#            train acc : 0.0258961  /  test acc : 0.0210789
# epoch 77 - train loss : 0.6632082  /  test loss : 0.6659341
#            train acc : 0.0259474  /  test acc : 0.0246579
# epoch 78 - train loss : 0.6631864  /  test loss : 0.6850889
#            train acc : 0.0258421  /  test acc : 0.0159342
# epoch 79 - train loss : 0.6631661  /  test loss : 0.6899116
#            train acc : 0.0259961  /  test acc : 0.0156711
# epoch 80 - train loss : 0.6630985  /  test loss : 0.7832714
#            train acc : 0.0261763  /  test acc : 0.0073947
# epoch 81 - train loss : 0.6631225  /  test loss : 0.6964090
#            train acc : 0.0260539  /  test acc : 0.0139079
# epoch 82 - train loss : 0.6629944  /  test loss : 0.6644039
#            train acc : 0.0265447  /  test acc : 0.0257763
# epoch 83 - train loss : 0.6629906  /  test loss : 0.6959568
#            train acc : 0.0262566  /  test acc : 0.0126842
# epoch 84 - train loss : 0.6630158  /  test loss : 0.6664430
#            train acc : 0.0264526  /  test acc : 0.0245395
# epoch 85 - train loss : 0.6629562  /  test loss : 0.6901509
#            train acc : 0.0262211  /  test acc : 0.0154868
# epoch 86 - train loss : 0.6629573  /  test loss : 0.6820245
#            train acc : 0.0259487  /  test acc : 0.0175395
# epoch 87 - train loss : 0.6628930  /  test loss : 0.6745175
#            train acc : 0.0262039  /  test acc : 0.0227237
# epoch 88 - train loss : 0.6629508  /  test loss : 0.7108374
#            train acc : 0.0263171  /  test acc : 0.0111184
# epoch 89 - train loss : 0.6629544  /  test loss : 0.6692817
#            train acc : 0.0260605  /  test acc : 0.0229605
# epoch 90 - train loss : 0.6628731  /  test loss : 0.7184830
#            train acc : 0.0261974  /  test acc : 0.0104605
# epoch 91 - train loss : 0.6628470  /  test loss : 0.6656696
#            train acc : 0.0266276  /  test acc : 0.0241053
# epoch 92 - train loss : 0.6628416  /  test loss : 0.7538493
#            train acc : 0.0264039  /  test acc : 0.0084079
# epoch 93 - train loss : 0.6628773  /  test loss : 0.6738280
#            train acc : 0.0265250  /  test acc : 0.0190921
# epoch 94 - train loss : 0.6628064  /  test loss : 0.7848105
#            train acc : 0.0267513  /  test acc : 0.0072632
# epoch 95 - train loss : 0.6627108  /  test loss : 0.6759892
#            train acc : 0.0266237  /  test acc : 0.0184211
# epoch 96 - train loss : 0.6627783  /  test loss : 0.6711488
#            train acc : 0.0263908  /  test acc : 0.0225000
# epoch 97 - train loss : 0.6627167  /  test loss : 0.7399791
#            train acc : 0.0267737  /  test acc : 0.0093026
# epoch 98 - train loss : 0.6626359  /  test loss : 0.6683180
#            train acc : 0.0266816  /  test acc : 0.0235000
# epoch 99 - train loss : 0.6626647  /  test loss : 0.6643736
#            train acc : 0.0268987  /  test acc : 0.0259474
# epoch 100 - train loss : 0.6626138  /  test loss : 0.6737899
#            train acc : 0.0266447  /  test acc : 0.0208421
# @@@@@@@ save model : epoch 100
# training complete! - calculation time : 872.3956429958344   seconds
