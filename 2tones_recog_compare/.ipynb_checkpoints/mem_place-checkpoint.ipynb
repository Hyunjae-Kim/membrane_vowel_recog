# %%
import os
import time
import shutil
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils as utils
import torch.nn.init as init
from torchvision import datasets

# %%
data_type = 'mem'
model_num = 2
time_len =  0.2  ## ms

point_len = int(np.ceil(time_len*5))
fc_len = int(point_len/32)+1

# %%
class Model(nn.Module):
    def __init__(self, loss):
        super(Model, self).__init__()
        input_c = 6
        channel = 32
        self.conv1 = nn.Sequential(
            nn.Conv1d(input_c, channel, kernel_size=5, stride=2, padding=2),
            nn.LeakyReLU(negative_slope=0.1),
            nn.BatchNorm1d(channel))
        self.conv2 = nn.Sequential(
            nn.Conv1d(channel, channel*2, kernel_size=5, stride=2, padding=2),
            nn.LeakyReLU(negative_slope=0.1),
            nn.BatchNorm1d(channel*2))
        self.conv3 = nn.Sequential(
            nn.Conv1d(channel*2, channel*2, kernel_size=5, stride=2, padding=2),
            nn.LeakyReLU(negative_slope=0.1),
            nn.BatchNorm1d(channel*2))
        self.conv4 = nn.Sequential(
            nn.Conv1d(channel*2, channel*4, kernel_size=5, stride=2, padding=2),
            nn.LeakyReLU(negative_slope=0.1),
            nn.BatchNorm1d(channel*4))
        self.conv5 = nn.Sequential(
            nn.Conv1d(channel*4, channel*4, kernel_size=5, stride=2, padding=2),
            nn.LeakyReLU(negative_slope=0.1),
            nn.BatchNorm1d(channel*4))
        self.fc1 = nn.Sequential(
            nn.Linear(channel*4*fc_len, 1024),
            nn.LeakyReLU(negative_slope=0.1),
            nn.BatchNorm1d(1024))
        self.fc2 = nn.Sequential(
            nn.Linear(1024, 20),
            nn.Softmax(dim=1))
        self.loss = loss
        
    def forward(self, data, target):
        x = self.conv1(data)
#         print('1',x.size())
        x = self.conv2(x)
#         print('2',x.size())
        x = self.conv3(x)
#         print('3',x.size())
        x = self.conv4(x)
#         print('4',x.size())
        x = self.conv5(x)
#         print('5',x.size())
        x = x.view(x.size()[0],-1)
#         print('fc', x.size())
        x = self.fc1(x)
#         print('8',x.size())
        h = self.fc2(x)
#         print('9',h.size())
        
        l = self.loss(h, target)
        return l, h, target

# %%
def train(model, trainX, trainY, batch, device, optimizer, train_loss, train_acc):
    model.train()
    dloss = 0
    dacc = 0
    
    rand = torch.randperm(trainX.size()[0])
    trainX = trainX[rand]
    trainY = trainY[rand]
    
    for i in range(batch[0]):
        optimizer.zero_grad()
        loss, output, target = model(trainX[i*batch[1]:(i+1)*batch[1]], trainY[i*batch[1]:(i+1)*batch[1]])
        loss = loss.sum()
        loss.backward()
        optimizer.step()
        _, output = torch.topk(output, 2)
        output, _ = output.sort()
        _, target = torch.topk(target, 2)
        target, _ = target.sort()
        
        dloss += loss.cpu().item()
        dacc += torch.sum(torch.sum(output==target, 1)==2).item()
        
    train_loss.append(dloss/batch[0])
    train_acc.append(dacc/(batch[0]*batch[1]))
    return train_loss, train_acc

def test(model, testX, testY, device, test_loss, test_acc):
    model.eval()
    loss, output, target = model(testX, testY)
    loss = loss.sum()
    
    _, output = torch.topk(output, 2)
    output, _ = output.sort()
    _, target = torch.topk(target, 2)
    target, _ = target.sort()
    
    test_loss.append(loss.cpu().item())
    test_acc.append(torch.sum(torch.sum(output==target, 1)==2).item()/len(testX))
    return test_loss, test_acc, output, target

# %%
if __name__=='__main__':
    print('[Training]%s_%.1f_model%d'%(data_type, time_len, model_num))
    torch.manual_seed(37)
    torch.cuda.manual_seed_all(37)
    torch.backends.cudnn.deterministic = True
    
    trainX = np.load('npy_data/%s/%s_%.1fms_trainX.npy'%(data_type, data_type, 1.0))
    trainY = np.load('npy_data/%s/%s_%.1fms_trainY.npy'%(data_type, data_type, 1.0))
    testX = np.load('npy_data/%s/%s_%.1fms_testX.npy'%(data_type, data_type, 1.0))
    testY = np.load('npy_data/%s/%s_%.1fms_testY.npy'%(data_type, data_type, 1.0))

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
    batch_num = 1000
    batch = [int(len(trainX)/batch_num), batch_num]
    
    trainX = torch.Tensor(trainX).to(device)[:,:,:point_len]
    trainY = torch.Tensor(trainY).to(device)
    testX = torch.Tensor(testX).to(device)[:,:,:point_len]
    testY = torch.Tensor(testY).to(device)
    print('mem data shape  -  %.1f ms'%time_len)
    print('train set :', np.shape(trainX) , np.shape(trainY))
    print('test set :', np.shape(testX) ,np.shape(testY))
# Out:
# [Training]mem_0.2_model2
# mem data shape  -  0.2 ms
# train set : torch.Size([760000, 6, 1]) torch.Size([760000, 20])
# test set : torch.Size([76000, 6, 1]) torch.Size([76000, 20])

# %%
    learning_rate = 0.0005
    loss_func=nn.BCELoss()
    model = nn.DataParallel(Model(loss_func)).to(device)
#     model = Model(loss_func).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=batch_num, eta_min = 3e-6)

#     model.load_state_dict(torch.load('ckpt/model%d/%s/%.1f_ckpt_1000.pt'%(model_num, data_type, time_len)))
    a = time.time()
    train_loss = []
    train_acc = []
    test_loss = []
    test_acc = []
    for epoch in range(101):
        train_loss, train_acc = train(model, trainX, trainY, batch, device, optimizer, train_loss, train_acc)
        test_loss, test_acc, output, target = test(model, testX, testY, device, test_loss, test_acc)
        scheduler.step()
        
        if epoch%1==0:
            print('epoch %d - train loss : %.7f  /  test loss : %.7f'%(epoch, train_loss[-1], test_loss[-1]))
            print('           train acc : %.7f  /  test acc : %.7f'%(train_acc[-1], test_acc[-1]))
        if epoch%50==0:
            print('@@@@@@@ save model : epoch %d'% epoch)
            torch.save(model.state_dict(),'ckpt/model%d_place/%s/%.1f_ckpt_%d.pt'%(model_num, data_type, time_len, epoch))
            np.savetxt('result/model%d_place/%s/%.1f_loss_tr.txt'%(model_num, data_type, time_len), train_loss)
            np.savetxt('result/model%d_place/%s/%.1f_loss_te.txt'%(model_num, data_type, time_len), test_loss)
            np.savetxt('result/model%d_place/%s/%.1f_acc_tr.txt'%(model_num, data_type, time_len), train_acc)
            np.savetxt('result/model%d_place/%s/%.1f_acc_te.txt'%(model_num, data_type, time_len), test_acc)
    print("training complete! - calculation time :", time.time()-a, '  seconds')
# Out:
# /opt/anaconda3/envs/khj/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:61: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# epoch 0 - train loss : 0.6738597  /  test loss : 0.6678832
#            train acc : 0.0243421  /  test acc : 0.0295132
# @@@@@@@ save model : epoch 0
# epoch 1 - train loss : 0.6657354  /  test loss : 0.6619527
#            train acc : 0.0353776  /  test acc : 0.0403684
# epoch 2 - train loss : 0.6624168  /  test loss : 0.6598714
#            train acc : 0.0408947  /  test acc : 0.0436447
# epoch 3 - train loss : 0.6603082  /  test loss : 0.6587433
#            train acc : 0.0444105  /  test acc : 0.0441974
# epoch 4 - train loss : 0.6588962  /  test loss : 0.6575237
#            train acc : 0.0464079  /  test acc : 0.0475132
# epoch 5 - train loss : 0.6578786  /  test loss : 0.6565648
#            train acc : 0.0478132  /  test acc : 0.0484868
# epoch 6 - train loss : 0.6570096  /  test loss : 0.6566822
#            train acc : 0.0496355  /  test acc : 0.0507237
# epoch 7 - train loss : 0.6562407  /  test loss : 0.6557618
#            train acc : 0.0509961  /  test acc : 0.0516842
# epoch 8 - train loss : 0.6556643  /  test loss : 0.6550564
#            train acc : 0.0518711  /  test acc : 0.0508553
# epoch 9 - train loss : 0.6550749  /  test loss : 0.6550111
#            train acc : 0.0527487  /  test acc : 0.0534211
# epoch 10 - train loss : 0.6546669  /  test loss : 0.6539706
#            train acc : 0.0536263  /  test acc : 0.0540000
# epoch 11 - train loss : 0.6542137  /  test loss : 0.6540052
# epoch 40 - train loss : 0.6483629  /  test loss : 0.6509857
#            train acc : 0.0643408  /  test acc : 0.0620526
# epoch 41 - train loss : 0.6482493  /  test loss : 0.6508048
#            train acc : 0.0641368  /  test acc : 0.0619211
# epoch 42 - train loss : 0.6480746  /  test loss : 0.6514028
#            train acc : 0.0647987  /  test acc : 0.0626053
# epoch 43 - train loss : 0.6480382  /  test loss : 0.6510006
#            train acc : 0.0646750  /  test acc : 0.0618553
# epoch 44 - train loss : 0.6478823  /  test loss : 0.6504836
#            train acc : 0.0651408  /  test acc : 0.0626053
# epoch 45 - train loss : 0.6477242  /  test loss : 0.6508613
#            train acc : 0.0651921  /  test acc : 0.0620000
# epoch 46 - train loss : 0.6476831  /  test loss : 0.6508037
#            train acc : 0.0655711  /  test acc : 0.0631053
# epoch 47 - train loss : 0.6475426  /  test loss : 0.6507699
#            train acc : 0.0655868  /  test acc : 0.0633026
# epoch 48 - train loss : 0.6474730  /  test loss : 0.6510571
#            train acc : 0.0659105  /  test acc : 0.0616053
# epoch 49 - train loss : 0.6473302  /  test loss : 0.6505035
#            train acc : 0.0658184  /  test acc : 0.0619342
# epoch 50 - train loss : 0.6472780  /  test loss : 0.6506039
#            train acc : 0.0659066  /  test acc : 0.0626316
# @@@@@@@ save model : epoch 50
# epoch 51 - train loss : 0.6471563  /  test loss : 0.6502655
#            train acc : 0.0660329  /  test acc : 0.0640789
# epoch 52 - train loss : 0.6470596  /  test loss : 0.6507977
#            train acc : 0.0661487  /  test acc : 0.0626184
# epoch 53 - train loss : 0.6469971  /  test loss : 0.6503146
#            train acc : 0.0665276  /  test acc : 0.0629211
# epoch 54 - train loss : 0.6468984  /  test loss : 0.6506175
#            train acc : 0.0666000  /  test acc : 0.0634079
# epoch 55 - train loss : 0.6468187  /  test loss : 0.6507272
#            train acc : 0.0665329  /  test acc : 0.0641053
# epoch 56 - train loss : 0.6466901  /  test loss : 0.6505615
#            train acc : 0.0669132  /  test acc : 0.0625263
# epoch 57 - train loss : 0.6466302  /  test loss : 0.6504143
#            train acc : 0.0672645  /  test acc : 0.0639342
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-31a1868cb0be> in <module>
#      13 test_acc = []
#      14 for epoch in range(101):
# ---> 15     train_loss, train_acc = train(model, trainX, trainY, batch, device, optimizer, train_loss, train_acc)
#      16     test_loss, test_acc, output, target = test(model, testX, testY, device, test_loss, test_acc)
#      17     scheduler.step()
#
# <ipython-input-4-a630266f5841> in train(model, trainX, trainY, batch, device, optimizer, train_loss, train_acc)
#      10     for i in range(batch[0]):
#      11         optimizer.zero_grad()
# ---> 12         loss, output, target = model(trainX[i*batch[1]:(i+1)*batch[1]], trainY[i*batch[1]:(i+1)*batch[1]])
#      13         loss = loss.sum()
#      14         loss.backward()
#
# /opt/anaconda3/envs/khj/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /opt/anaconda3/envs/khj/lib/python3.7/site-packages/torch/nn/parallel/data_parallel.py in forward(self, *inputs, **kwargs)
#     141             return self.module(*inputs[0], **kwargs[0])
#     142         replicas = self.replicate(self.module, self.device_ids[:len(inputs)])
# --> 143         outputs = self.parallel_apply(replicas, inputs, kwargs)
#     144         return self.gather(outputs, self.output_device)
#     145
#
# /opt/anaconda3/envs/khj/lib/python3.7/site-packages/torch/nn/parallel/data_parallel.py in parallel_apply(self, replicas, inputs, kwargs)
#     151
#     152     def parallel_apply(self, replicas, inputs, kwargs):
# --> 153         return parallel_apply(replicas, inputs, kwargs, self.device_ids[:len(replicas)])
#     154
#     155     def gather(self, outputs, output_device):
#
# /opt/anaconda3/envs/khj/lib/python3.7/site-packages/torch/nn/parallel/parallel_apply.py in parallel_apply(modules, inputs, kwargs_tup, devices)
#      73             thread.start()
#      74         for thread in threads:
# ---> 75             thread.join()
#      76     else:
#      77         _worker(0, modules[0], inputs[0], kwargs_tup[0], devices[0])
#
# /opt/anaconda3/envs/khj/lib/python3.7/threading.py in join(self, timeout)
#    1042
#    1043         if timeout is None:
# -> 1044             self._wait_for_tstate_lock()
#    1045         else:
#    1046             # the behavior of a negative timeout isn't documented, but
#
# /opt/anaconda3/envs/khj/lib/python3.7/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1058         if lock is None:  # already determined that the C code is done
#    1059             assert self._is_stopped
# -> 1060         elif lock.acquire(block, timeout):
#    1061             lock.release()
#    1062             self._stop()
#
# KeyboardInterrupt:
