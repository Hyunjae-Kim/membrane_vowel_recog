# %%
import os
import time
import shutil
import argparse
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils as utils
import torch.nn.init as init
from torchvision import datasets

model_num = 2
data_num = 1
point_len = 5
ch_num = 10
time_len =  point_len/10
fc_len = int(point_len/32)+1

# %%
class Model(nn.Module):
    def __init__(self, loss):
        super(Model, self).__init__()
        input_c = ch_num
        channel = 32
        self.conv1 = nn.Sequential(
            nn.Conv1d(input_c, channel, kernel_size=5, stride=2, padding=2),
            nn.LeakyReLU(negative_slope=0.1),
            nn.BatchNorm1d(channel))
        self.conv2 = nn.Sequential(
            nn.Conv1d(channel, channel*2, kernel_size=5, stride=2, padding=2),
            nn.LeakyReLU(negative_slope=0.1),
            nn.BatchNorm1d(channel*2))
        self.conv3 = nn.Sequential(
            nn.Conv1d(channel*2, channel*2, kernel_size=5, stride=2, padding=2),
            nn.LeakyReLU(negative_slope=0.1),
            nn.BatchNorm1d(channel*2))
        self.conv4 = nn.Sequential(
            nn.Conv1d(channel*2, channel*4, kernel_size=5, stride=2, padding=2),
            nn.LeakyReLU(negative_slope=0.1),
            nn.BatchNorm1d(channel*4))
        self.conv5 = nn.Sequential(
            nn.Conv1d(channel*4, channel*4, kernel_size=5, stride=2, padding=2),
            nn.LeakyReLU(negative_slope=0.1),
            nn.BatchNorm1d(channel*4))
        self.fc1 = nn.Sequential(
            nn.Linear(channel*4*fc_len, 1024),
            nn.LeakyReLU(negative_slope=0.1),
            nn.BatchNorm1d(1024))
        self.fc2 = nn.Sequential(
            nn.Linear(1024, 20),
            nn.Softmax(dim=1))
        self.loss = loss
        
    def forward(self, data, target):
        x = self.conv1(data)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.conv5(x).contiguous()
        x = x.view(x.size()[0],-1)
        x = self.fc1(x)
        h = self.fc2(x)
        
        l = self.loss(h, target)
        return l, h, target

def train(model, trainX, trainY, batch, device, optimizer, train_loss, train_acc):
    model.train()
    dloss = 0
    dacc = 0
    
    rand = torch.randperm(trainX.size()[0])
    trainX = trainX[rand]
    trainY = trainY[rand]
    
    for i in range(batch[0]):
        optimizer.zero_grad()
        loss, output, target = model(trainX[i*batch[1]:(i+1)*batch[1]], trainY[i*batch[1]:(i+1)*batch[1]])
        loss = loss.sum()
        loss.backward()
        optimizer.step()
        
        _, output = torch.max(output, 1)
        _, target = torch.max(target, 1)

        dloss += loss.cpu().item()
        dacc += (output==target).sum().item()
        
    train_loss.append(dloss/batch[0])
    train_acc.append(dacc/(batch[0]*batch[1]))
    return train_loss, train_acc

def test(model, testX, testY, batch, device, train_loss, train_acc):
    model.eval()
    dloss = 0
    dacc = 0
    
    for i in range(batch[0]):
        optimizer.zero_grad()
        loss, output, target = model(trainX[i*batch[1]:(i+1)*batch[1]], trainY[i*batch[1]:(i+1)*batch[1]])
        loss = loss.sum()
        
        _, output = torch.max(output, 1)
        _, target = torch.max(target, 1)

        dloss += loss.cpu().item()
        dacc += (output==target).sum().item()
        
    test_loss.append(dloss/batch[0])
    test_acc.append(dacc/(batch[0]*batch[1]))
    return test_loss, test_acc

# %%
if __name__=='__main__':
    print('[Training]%dch_%.1f_model%d'%(ch_num, time_len, model_num))
    torch.manual_seed(37)
    torch.cuda.manual_seed_all(37)
    torch.backends.cudnn.deterministic = True
    
    trainX = np.load('../../npy_data/pure_data%d/%dch/%dch_%.1fms_trainX.npy'%(data_num, ch_num, ch_num, time_len))
    trainY = np.load('../../npy_data/pure_data%d/%dch/%dch_%.1fms_trainY.npy'%(data_num, ch_num, ch_num, time_len))
    testX = np.load('../../npy_data/pure_data%d/%dch/%dch_%.1fms_testX.npy'%(data_num, ch_num, ch_num, time_len))
    testY = np.load('../../npy_data/pure_data%d/%dch/%dch_%.1fms_testY.npy'%(data_num, ch_num, ch_num, time_len))

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
    batch_num = int(len(testX)/2)
    batch = [int(len(trainX)/batch_num), batch_num]
    batch_te = [int(len(testX)/batch_num), batch_num]
    
    trainX = torch.Tensor(trainX).to(device)
    trainY = torch.Tensor(trainY).to(device)
    testX = torch.Tensor(testX).to(device)
    testY = torch.Tensor(testY).to(device)
    print('%dch data shape  -  %.1f ms'%(ch_num, time_len))
    print('train set :', np.shape(trainX) , np.shape(trainY))
    print('test set :', np.shape(testX) ,np.shape(testY))
    
    
    learning_rate = 0.00005
    loss_func=nn.BCELoss()
    model = nn.DataParallel(Model(loss_func)).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=batch_num, eta_min = 3e-6)

#     model.load_state_dict(torch.load('ckpt/model%d_mem/%.1f_ckpt_2000.pt'%(model_num, time_len)))
    a = time.time()
    train_loss = []
    train_acc = []
    test_loss = []
    test_acc = []
    for epoch in range(1001):
        train_loss, train_acc = train(model, trainX, trainY, batch, device, optimizer, train_loss, train_acc)
        test_loss, test_acc = test(model, testX, testY, batch_te, device, test_loss, test_acc)
        scheduler.step()
        
        if epoch%10==0: 
            print('epoch %d - train loss : %.7f  /  test loss : %.7f'%(epoch, train_loss[-1], test_loss[-1]))
            print('           train acc : %.7f  /  test acc : %.7f'%(train_acc[-1], test_acc[-1]))
        if epoch%50==0:
            print('@@@@@@@ save model : epoch %d'% epoch)
            torch.save(model.state_dict(),'../../ckpt/model%d/pure_data%d/%dch/%.1f_ckpt_%d.pt'%(model_num, data_num, ch_num, time_len, epoch))
            np.savetxt('../../result/model%d/pure_data%d/%dch/%.1f_loss_tr.txt'%(model_num, data_num, ch_num, time_len), train_loss)
            np.savetxt('../../result/model%d/pure_data%d/%dch/%.1f_loss_te.txt'%(model_num, data_num, ch_num, time_len), test_loss)
            np.savetxt('../../result/model%d/pure_data%d/%dch/%.1f_acc_tr.txt'%(model_num, data_num, ch_num, time_len), train_acc)
            np.savetxt('../../result/model%d/pure_data%d/%dch/%.1f_acc_te.txt'%(model_num, data_num, ch_num, time_len), test_acc)
    print("training complete! - calculation time :", time.time()-a, '  seconds\n\n')
# Out:
# [Training]10ch_0.5_model2
# 10ch data shape  -  0.5 ms
# train set : torch.Size([640000, 10, 5]) torch.Size([640000, 20])
# test set : torch.Size([160000, 10, 5]) torch.Size([160000, 20])
# /opt/anaconda3/envs/khj/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:61: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# epoch 0 - train loss : 0.3928504  /  test loss : 0.3975329
#            train acc : 0.0756813  /  test acc : 0.0000000
# @@@@@@@ save model : epoch 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-b5cfd275bf84> in <module>
#      38     test_acc = []
#      39     for epoch in range(1001):
# ---> 40         train_loss, train_acc = train(model, trainX, trainY, batch, device, optimizer, train_loss, train_acc)
#      41         test_loss, test_acc = test(model, testX, testY, batch_te, device, test_loss, test_acc)
#      42         scheduler.step()
#
# <ipython-input-2-b6e495875da3> in train(model, trainX, trainY, batch, device, optimizer, train_loss, train_acc)
#      57     for i in range(batch[0]):
#      58         optimizer.zero_grad()
# ---> 59         loss, output, target = model(trainX[i*batch[1]:(i+1)*batch[1]], trainY[i*batch[1]:(i+1)*batch[1]])
#      60         loss = loss.sum()
#      61         loss.backward()
#
# /opt/anaconda3/envs/khj/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /opt/anaconda3/envs/khj/lib/python3.7/site-packages/torch/nn/parallel/data_parallel.py in forward(self, *inputs, **kwargs)
#     141             return self.module(*inputs[0], **kwargs[0])
#     142         replicas = self.replicate(self.module, self.device_ids[:len(inputs)])
# --> 143         outputs = self.parallel_apply(replicas, inputs, kwargs)
#     144         return self.gather(outputs, self.output_device)
#     145
#
# /opt/anaconda3/envs/khj/lib/python3.7/site-packages/torch/nn/parallel/data_parallel.py in parallel_apply(self, replicas, inputs, kwargs)
#     151
#     152     def parallel_apply(self, replicas, inputs, kwargs):
# --> 153         return parallel_apply(replicas, inputs, kwargs, self.device_ids[:len(replicas)])
#     154
#     155     def gather(self, outputs, output_device):
#
# /opt/anaconda3/envs/khj/lib/python3.7/site-packages/torch/nn/parallel/parallel_apply.py in parallel_apply(modules, inputs, kwargs_tup, devices)
#      73             thread.start()
#      74         for thread in threads:
# ---> 75             thread.join()
#      76     else:
#      77         _worker(0, modules[0], inputs[0], kwargs_tup[0], devices[0])
#
# /opt/anaconda3/envs/khj/lib/python3.7/threading.py in join(self, timeout)
#    1042
#    1043         if timeout is None:
# -> 1044             self._wait_for_tstate_lock()
#    1045         else:
#    1046             # the behavior of a negative timeout isn't documented, but
#
# /opt/anaconda3/envs/khj/lib/python3.7/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1058         if lock is None:  # already determined that the C code is done
#    1059             assert self._is_stopped
# -> 1060         elif lock.acquire(block, timeout):
#    1061             lock.release()
#    1062             self._stop()
#
# KeyboardInterrupt:
